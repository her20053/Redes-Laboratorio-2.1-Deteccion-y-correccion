# %%
import matplotlib.pyplot as plt

# %%
lista_parejas = []

with open("simulacion.txt", "r") as file:
    while file.readline() != "":
        elemento1 = file.readline().strip("\n")
        elemento2 = file.readline().strip("\n")
        pareja = (elemento1, elemento2)
        print(pareja)
        lista_parejas.append(pareja)

print(lista_parejas)
# Out:
# ('ToZju]ngdE', 'XFaMCwdKnM')
# ('WPoYVGFTQD', 'WPoYVGFTQD')
# ('PUwHQapHOj', 'HfZSQDkvin')
# ('SWmqbilGmS', 'SWmqbilGmS')
# ('KmmeRgyNgL', 'DADIuqYxWk')
# ('xmBpIldZaY', 'xmBpIldZaY')
# ('VcDyuCxoYu', 'lnfmoHwsiF')
# ('REDrnjxBhD', 'REDrnjxBhD')
# ('seYRpWYvVT', 'mxwsZnfKyF')
# ('vvdzvepmZH', 'vvdzvepmZH')
# ('ENLVzOIOHX', 'JgnuDdeqGK')
# ('uAbrPmpyhH', 'uAbrPmpyhH')
# ('nHftzUivkc', 'lsEgkbvVrH')
# ('LahvNVThoM', 'LahvNVThoM')
# ('osfvLlSvgl', 'bjuGNpBIrm')
# ('IExXLeiECM', 'IEpXLuiECM')
# ('nYpuOvThzI', 'AFtWzLPVRa')
# ('DtQzIdmYZe', 'DtQzIdmYZe')
# ('yFkkTyZcFg', 'tsFjDcZGjV')
# ('cHrrWFfeni', 'cHrrWFfeni')
# ('xcDHAqgEJV', 'GEpNdqispe')
# ('JVPubhugku', 'JVPubhugku')
# ('pvyonMJPYa', 'JtmzeVZoQi')
# ('DLlRvfTCqY', 'DLlRvfTCqY')
# ('AVaGyBr\twx', 'CEGtQdUkgH')
# ('LBignkvkWs', 'LBignkvkWs')
# ('tNrufSzson', 'moWvePlMDk')
# ('yUcAkZPduJ', 'yUcAkZPduJ')
# ('lPkGztZldi', 'eeVahMsGwK')
# ('vsxboCMnbu', 'vsxboCMnbu')
# ('NMjTYQfjBw', 'BMkwqvDrwa')
# ('cQOesLSbKk', 'cQOesLSbKk')
# ...
